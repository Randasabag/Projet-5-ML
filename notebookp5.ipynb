# %%
import numpy as np # linear algebra
import pandas as pd

# %%
df=pd.read_csv('/Users/randaalsabbagh/Desktop/MACHINE_LEARNING/P5/QueryResultsP5.csv', sep=',')
df.head(60)
# Out:
#        LastActivityDate                                              Title  \
# 0   2022-08-29 20:14:36                   Determine the type of an object?
# 1   2022-07-02 05:29:08             Why can't Python parse this JSON data?
# 2   2023-11-20 22:23:13   Best way to convert string to bytes in Python 3?
# 3   2022-11-09 15:44:56                  Display number with leading zeros
# 4   2023-07-28 17:04:02  Create a Pandas Dataframe by appending one row...
# 5   2022-11-23 08:30:50  Should I use 'has_key()' or 'in' on Python dicts?
# 6   2022-08-15 07:57:04      How to check if type of a variable is string?
# 7   2023-01-27 10:02:02  Which exception should I raise on bad/illegal ...
# 8   2022-05-31 17:20:40         Using @property versus getters and setters
# 9   2023-01-29 17:03:17  How can I check if a string represents an int,...
# 10  2023-08-23 15:00:24  How can I use pickle to save a dict (or any ot...
# 11  2022-08-28 19:10:16     Getting a map() to return a list in Python 3.x
# 12  2023-11-07 17:49:05                       How can I pivot a dataframe?
# 13  2020-01-31 06:45:21         Determine if variable is defined in Python
# 14  2022-07-05 21:20:38                           Reading JSON from a file
# 15  2021-03-14 20:21:58                    Python Dictionary Comprehension
# 16  2022-09-03 09:33:18  Is there a way to perform "if" in python's lam...
# 17  2020-02-18 13:06:27         Convert a list of characters into a string
# 18  2023-11-03 07:44:03  How to add to the PYTHONPATH in Windows, so it...
# 19  2023-03-21 08:25:43                     How to find list intersection?
# 20  2023-10-13 14:51:45               Redirect stdout to a file in Python?
# 21  2021-06-25 14:13:28  Store output of subprocess.Popen call in a string
# 22  2022-12-19 12:27:33        Why does range(start, end) not include end?
# 23  2024-03-21 04:06:15         Convert a python dict to a string and back
# 24  2022-11-02 08:35:13  How do you properly determine the current scri...
# 25  2019-04-20 01:29:27   How can I check if a key exists in a dictionary?
# 26  2022-08-06 19:04:52             Double Iteration in List Comprehension
# 27  2022-03-30 14:18:48  What's the difference between `raw_input()` an...
# 28  2022-05-24 08:21:27  NumPy array initialization (fill with identica...
# 29  2021-06-28 09:57:35                  Python function global variables?
# 30  2022-05-08 17:52:09                   Get loop count inside a for-loop
# 31  2023-05-14 01:50:26  How do I convert all of the items in a list to...
# 32  2022-12-29 23:24:40  'str' object has no attribute 'decode'. Python...
# 33  2022-06-09 08:35:13  Access multiple elements of list knowing their...
# 34  2022-04-05 10:52:38  Take the content of a list and append it to an...
# 35  2023-02-02 18:17:15           List files ONLY in the current directory
# 36  2023-04-24 15:57:39  Error "Import Error: No module named numpy" on...
# 37  2023-12-28 20:34:37  Are nested try/except blocks in Python a good ...
# 38  2015-11-06 10:04:38  How do I change the string representation of a...
# 39  2024-02-13 18:27:19  Scraping: SSL: CERTIFICATE_VERIFY_FAILED error...
# 40  2017-10-01 15:04:38          Python: access class property from string
# 41  2022-07-30 13:07:53  How to count the frequency of the elements in ...
# 42  2022-03-01 03:37:01  Find first element in a sequence that matches ...
# 43  2021-07-13 19:58:45                  Confused by python file mode "w+"
# 44  2022-05-01 16:39:08                          Python import csv to list
# 45  2022-10-31 10:35:27                            Compute list difference
# 46  2021-03-01 22:12:03    How do I pass a method as a parameter in Python
# 47  2022-12-12 17:00:15  How to reliably open a file in the same direct...
# 48  2021-02-09 11:47:31  ModuleNotFoundError: What does it mean __main_...
# 49  2023-01-06 18:48:48     ImportError: No module named matplotlib.pyplot
#
#                                                  Tags  Score
# 0                 <python><dictionary><types><typeof>   2164
# 1                             <python><json><parsing>   1503
# 2    <python><string><character-encoding><python-3.x>   1482
# 3                <python><integer><string-formatting>   1419
# 4                 <python><pandas><dataframe><append>   1399
# 5                                <python><dictionary>   1122
# 6                  <python><string><variables><types>   1051
# 7                      <python><exception><arguments>    820
# 8                 <python><properties><getter-setter>    798
# 9                           <python><string><integer>    733
# 10                       <python><dictionary><pickle>    702
# 11           <python><list><python-3.x><map-function>    645
# 12     <python><pandas><group-by><pivot><pivot-table>    625
# 13                       <python><variables><defined>    553
# 14                                     <python><json>    550
# 15           <python><dictionary><list-comprehension>    525
# 16             <python><lambda><conditional-operator>    512
# 17                                   <python><string>    489
# 18  <python><windows><environment-variables><pytho...    475
# 19                     <python><arrays><intersection>    447
# 20                                   <python><stdout>    440
# 21                               <python><subprocess>    430
# 22                                    <python><range>    426
# 23          <python><json><dictionary><serialization>    415
# 24                  <python><path><working-directory>    409
# 25                                           <python>    404
# 26                       <python><list-comprehension>    402
# 27                        <python><python-3.x><input>    400
# 28                            <python><arrays><numpy>    396
# 29                         <python><global-variables>    372
# 30                                 <python><for-loop>    361
# 31                            <python><list><casting>    356
# 32                               <python><python-3.x>    352
# 33      <python><python-3.x><list><indexing><element>    343
# 34                                     <python><list>    341
# 35                                           <python>    330
# 36         <python><python-3.x><numpy><import><scipy>    326
# 37                                           <python>    320
# 38             <python><string><python-3.x><printing>    309
# 39  <python><web-scraping><beautifulsoup><scrapy><...    303
# 40                                   <python><syntax>    290
# 41                          <python><list><frequency>    290
# 42                                <python><predicate>    284
# 43                                 <python><file><io>    277
# 44                                      <python><csv>    270
# 45                                     <python><list>    264
# 46                        <python><parameter-passing>    262
# 47                                <python><directory>    260
# 48        <python><module><python-3.6><python-import>    259
# 49                               <python><matplotlib>    259

# %%
print(df.shape)
# Out:
# (50, 4)

# %%
df.isnull().sum()
# Out:
# LastActivityDate    0
# Title               0
# Tags                0
# Score               0
# dtype: int64

# %%
df['Title'].duplicated().sum()
# Out:
# 0

# %%
df.nunique()
# Out:
# LastActivityDate    50
# Title               50
# Tags                47
# Score               48
# dtype: int64
